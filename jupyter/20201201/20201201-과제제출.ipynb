# %%
import requests
from bs4 import BeautifulSoup


headers = {
    'User-Agent': (
        'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3) '
        'AppleWebKit/537.36 (KHTML, like Gecko) '
        'Chrome/72.0.3626.121 Safari/537.36'
    ),
}


def get_like_count(song_no_list):
    api_url = "https://www.melon.com/commonlike/getSongLike.json"
    params = {"contsIds": song_no_list}
    res = requests.get(api_url, params=params, headers=headers)
    res.raise_for_status()
    response = res.json()
    like_list = response["contsLike"]
    like_dict = {
        str(song["CONTSID"]): song["SUMMCNT"]
        for song in like_list}
    return like_dict


def get_song_list():
    res = requests.get("http://www.melon.com/chart/index.htm", headers=headers)
    res.raise_for_status()
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    tr_tag_list = soup.select('.d_song_list tbody tr')

    song_list = []

    for rank, tr_tag in enumerate(tr_tag_list, 1):
        song_no = tr_tag["data-song-no"]
        song_tag = tr_tag.select_one('a[href*=playSong]')
        album_tag = tr_tag.select_one('.wrap_song_info a[href*=goAlbumDetail]')
        artist_tag = tr_tag.select_one('a[href*=goArtistDetail]')
        
        song = {
            'song_no': song_no,
            'title': song_tag.text,
            'album': album_tag.text,
            'artist': artist_tag.text,
            'rank': rank,
        }
        song_list.append(song)

    song_no_list = [song["song_no"] for song in song_list]
    like_dict = get_like_count(song_no_list)

    for song in song_list:
        like_count = like_dict[song["song_no"]]
        song["like"] = like_count

    return song_list

# %%
melon_top100 = get_song_list()
melon_top100
# Out:
# [{'song_no': '33077590',
#   'title': 'VVS (Feat. JUSTHIS) (Prod. GroovyRoom)',
#   'album': '쇼미더머니 9 Episode 1',
#   'artist': '미란이',
#   'rank': 1,
#   'like': 94347},
#  {'song_no': '32872978',
#   'title': 'Dynamite',
#   'album': 'Dynamite (DayTime Version)',
#   'artist': '방탄소년단',
#   'rank': 2,
#   'like': 360682},
#  {'song_no': '33013877',
#   'title': '잠이 오질 않네요',
#   'album': '잠이 오질 않네요',
#   'artist': '장범준',
#   'rank': 3,
#   'like': 82061},
#  {'song_no': '32998018',
#   'title': '힘든 건 사랑이 아니다',
#   'album': '힘든 건 사랑이 아니다',
#   'artist': '임창정',
#   'rank': 4,
#   'like': 78971},
#  {'song_no': '33077234',
#   'title': 'Life Goes On',
#   'album': 'BE',
#   'artist': '방탄소년단',
#   'rank': 5,
#   'like': 150052},
#  {'song_no': '32961718',
#   'title': 'Lovesick Girls',
#   'album': 'THE ALBUM',
#   'artist': 'BLACKPINK',
#   'rank': 6,
#   'like': 150233},
#  {'song_no': '32794652',
#   'title': '취기를 빌려 (취향저격 그녀 X 산들)',
#   'album': '취기를 빌려 (취향저격 그녀 X 산들)',
#   'artist': '산들',
#   'rank': 7,
#   'like': 156888},
#  {'song_no': '33077591',
#   'title': 'Freak (Prod. Slom)',
#   'album': '쇼미더머니 9 Episode 1',
#   'artist': '릴보이 (lIlBOI)',
#   'rank': 8,
#   'like': 35758},
#  {'song_no': '33061995',
#   'title': '밤하늘의 별을(2020)',
#   'album': '밤하늘의 별을(2020)',
#   'artist': '경서',
#   'rank': 9,
#   'like': 41575},
#  {'song_no': '3894276',
#   'title': '오래된 노래',
#   'album': '오래된 노래',
#   'artist': '스탠딩 에그',
#   'rank': 10,
#   'like': 200112},
#  {'song_no': '32962258',
#   'title': 'Savage Love (Laxed - Siren Beat) (BTS Remix)',
#   'album': 'Savage Love (Laxed - Siren Beat) [BTS Remix]',
#   'artist': 'Jawsh 685',
#   'rank': 11,
#   'like': 128323},
#  {'song_no': '32978341',
#   'title': "DON'T TOUCH ME",
#   'album': "DON'T TOUCH ME",
#   'artist': '환불원정대',
#   'rank': 12,
#   'like': 157899},
#  {'song_no': '32871975',
#   'title': '내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)',
#   'album': '내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)',
#   'artist': '규현 (KYUHYUN)',
#   'rank': 13,
#   'like': 80470},
#  {'song_no': '33001672',
#   'title': '딩가딩가 (Dingga)',
#   'album': '딩가딩가 (Dingga)',
#   'artist': '마마무 (Mamamoo)',
#   'rank': 14,
#   'like': 48781},
#  {'song_no': '32853712',
#   'title': 'When We Disco (Duet with 선미)',
#   'album': 'When We Disco',
#   'artist': '박진영',
#   'rank': 15,
#   'like': 67007},
#  {'song_no': '32061975',
#   'title': '어떻게 이별까지 사랑하겠어, 널 사랑하는 거지',
#   'album': '항해',
#   'artist': 'AKMU (악동뮤지션)',
#   'rank': 16,
#   'like': 324195},
#  {'song_no': '33077588',
#   'title': '원해 (Feat. 팔로알토) (Prod. 코드 쿤스트)',
#   'album': '쇼미더머니 9 Episode 1',
#   'artist': '스윙스',
#   'rank': 17,
#   'like': 22472},
#  {'song_no': '33061829',
#   'title': '뻔한남자',
#   'album': '뻔한남자',
#   'artist': '이승기',
#   'rank': 18,
#   'like': 30712},
#  {'song_no': '33016659',
#   'title': 'I CAN’T STOP ME',
#   'album': 'Eyes wide open',
#   'artist': 'TWICE (트와이스)',
#   'rank': 19,
#   'like': 44688},
#  {'song_no': '32578498',
#   'title': '에잇(Prod.&Feat. SUGA of BTS)',
#   'album': '에잇',
#   'artist': '아이유',
#   'rank': 20,
#   'like': 330752},
#  {'song_no': '33043504',
#   'title': '가을밤에 든 생각',
#   'album': '잔나비 소곡집 l',
#   'artist': '잔나비',
#   'rank': 21,
#   'like': 51252},
#  {'song_no': '32003395',
#   'title': '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야',
#   'album': '멜로가 체질 OST Part 3',
#   'artist': '장범준',
#   'rank': 22,
#   'like': 270148},
#  {'song_no': '33011180',
#   'title': '나랑 같이 걸을래 (바른연애 길잡이 X 적재)',
#   'album': '나랑 같이 걸을래 (바른연애 길잡이 X 적재)',
#   'artist': '적재',
#   'rank': 23,
#   'like': 41638},
#  {'song_no': '32438894',
#   'title': '어떻게 지내 (Prod. By VAN.C)',
#   'album': '어떻게 지내',
#   'artist': '오반',
#   'rank': 24,
#   'like': 133343},
#  {'song_no': '32720013',
#   'title': 'How You Like That',
#   'album': 'How You Like That',
#   'artist': 'BLACKPINK',
#   'rank': 25,
#   'like': 164117},
#  {'song_no': '32156286',
#   'title': '늦은 밤 너의 집 앞 골목길에서',
#   'album': '늦은 밤 너의 집 앞 골목길에서',
#   'artist': '노을',
#   'rank': 26,
#   'like': 168164},
#  {'song_no': '32825454',
#   'title': '눈누난나 (NUNU NANA)',
#   'album': 'NUNA',
#   'artist': '제시 (Jessi)',
#   'rank': 27,
#   'like': 95407},
#  {'song_no': '32559782',
#   'title': 'Dolphin',
#   'album': 'NONSTOP',
#   'artist': '오마이걸 (OH MY GIRL)',
#   'rank': 28,
#   'like': 159371},
#  {'song_no': '32491274',
#   'title': '아로하',
#   'album': '슬기로운 의사생활 OST Part 3',
#   'artist': '조정석',
#   'rank': 29,
#   'like': 205454},
#  {'song_no': '32725013',
#   'title': '마리아 (Maria)',
#   'album': 'María',
#   'artist': '화사 (Hwa Sa)',
#   'rank': 30,
#   'like': 153184},
#  {'song_no': '31737197',
#   'title': '작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)',
#   'album': 'MAP OF THE SOUL : PERSONA',
#   'artist': '방탄소년단',
#   'rank': 31,
#   'like': 406370},
#  {'song_no': '32183386',
#   'title': 'Blueming',
#   'album': 'Love poem',
#   'artist': '아이유',
#   'rank': 32,
#   'like': 276419},
#  {'song_no': '32224272',
#   'title': 'METEOR',
#   'album': 'Boyhood',
#   'artist': '창모 (CHANGMO)',
#   'rank': 33,
#   'like': 242139},
#  {'song_no': '32777869',
#   'title': '거짓말이라도 해서 널 보고싶어',
#   'album': '거짓말이라도 해서 널 보고싶어',
#   'artist': '백지영',
#   'rank': 34,
#   'like': 48712},
#  {'song_no': '30962526',
#   'title': '모든 날, 모든 순간 (Every day, Every Moment)',
#   'album': '`키스 먼저 할까요?` OST Part.3',
#   'artist': '폴킴',
#   'rank': 35,
#   'like': 352216},
#  {'song_no': '33077235',
#   'title': '내 방을 여행하는 법',
#   'album': 'BE',
#   'artist': '방탄소년단',
#   'rank': 36,
#   'like': 90323},
#  {'song_no': '32570501',
#   'title': '서면역에서',
#   'album': '서면역에서',
#   'artist': '순순희',
#   'rank': 37,
#   'like': 32925},
#  {'song_no': '32808616',
#   'title': '홀로',
#   'album': '홀로',
#   'artist': '이하이',
#   'rank': 38,
#   'like': 118371},
#  {'song_no': '32999763',
#   'title': '놓아줘 (with 태연)',
#   'album': 'with HER',
#   'artist': 'Crush',
#   'rank': 39,
#   'like': 45861},
#  {'song_no': '33077236',
#   'title': 'Blue & Grey',
#   'album': 'BE',
#   'artist': '방탄소년단',
#   'rank': 40,
#   'like': 90841},
#  {'song_no': '32651098',
#   'title': '사랑은 지날수록 더욱 선명하게 남아',
#   'album': '한 걸음 : 흔적',
#   'artist': '전상근',
#   'rank': 41,
#   'like': 52937},
#  {'song_no': '31979846',
#   'title': 'Dance Monkey',
#   'album': 'The Kids Are Coming',
#   'artist': 'Tones And I',
#   'rank': 42,
#   'like': 142888},
#  {'song_no': '32055419',
#   'title': 'Memories',
#   'album': 'Memories',
#   'artist': 'Maroon 5',
#   'rank': 43,
#   'like': 147050},
#  {'song_no': '32525311',
#   'title': '사실 나는 (Feat.전건호)',
#   'album': '사실 나는',
#   'artist': '경서예지',
#   'rank': 44,
#   'like': 35219},
#  {'song_no': '30773554',
#   'title': 'Downtown Baby',
#   'album': 'Downtown Baby',
#   'artist': '블루 (BLOO)',
#   'rank': 45,
#   'like': 179878},
#  {'song_no': '33077589',
#   'title': '윈윈 (Feat. 개코, BewhY) (Prod. BewhY)',
#   'album': '쇼미더머니 9 Episode 1',
#   'artist': '허성현 (Rose de Penny)',
#   'rank': 46,
#   'like': 19119},
#  {'song_no': '31853557',
#   'title': '오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)',
#   'album': 'Red Moon : To You My Light',
#   'artist': '마크툽 (MAKTUB)',
#   'rank': 47,
#   'like': 221618},
#  {'song_no': '30244931',
#   'title': '봄날',
#   'album': 'YOU NEVER WALK ALONE',
#   'artist': '방탄소년단',
#   'rank': 48,
#   'like': 516046},
#  {'song_no': '32187544',
#   'title': '우리 왜 헤어져야 해',
#   'album': '우리 왜 헤어져야 해',
#   'artist': '신예영',
#   'rank': 49,
#   'like': 92027},
#  {'song_no': '32378104',
#   'title': '마음을 드려요',
#   'album': '사랑의 불시착 OST Part 11',
#   'artist': '아이유',
#   'rank': 50,
#   'like': 181135},
#  {'song_no': '32947184',
#   'title': 'Bad Boy',
#   'album': 'Bad Boy',
#   'artist': '청하',
#   'rank': 51,
#   'like': 50301},
#  {'song_no': '33002813',
#   'title': '사랑 못해, 남들 쉽게 다 하는 거',
#   'album': '사랑 못해, 남들 쉽게 다 하는 거',
#   'artist': '먼데이 키즈 (Monday Kiz)',
#   'rank': 52,
#   'like': 20733},
#  {'song_no': '14776',
#   'title': 'All I Want For Christmas Is You',
#   'album': 'Merry Christmas (Deluxe Anniversary Edition)',
#   'artist': 'Mariah Carey',
#   'rank': 53,
#   'like': 143985},
#  {'song_no': '31029291',
#   'title': '2002',
#   'album': 'Speak Your Mind (Deluxe)',
#   'artist': 'Anne-Marie',
#   'rank': 54,
#   'like': 344218},
#  {'song_no': '32998020',
#   'title': '소확행',
#   'album': '힘든 건 사랑이 아니다',
#   'artist': '임창정',
#   'rank': 55,
#   'like': 24351},
#  {'song_no': '32559781',
#   'title': '살짝 설렜어 (Nonstop)',
#   'album': 'NONSTOP',
#   'artist': '오마이걸 (OH MY GIRL)',
#   'rank': 56,
#   'like': 162167},
#  {'song_no': '33016550',
#   'title': '너도 아는',
#   'album': '너도 아는',
#   'artist': '폴킴',
#   'rank': 57,
#   'like': 32034},
#  {'song_no': '32790516',
#   'title': '다시 여기 바닷가',
#   'album': '다시 여기 바닷가',
#   'artist': '싹쓰리 (유두래곤, 린다G, 비룡)',
#   'rank': 58,
#   'like': 227758},
#  {'song_no': '33077238',
#   'title': '잠시',
#   'album': 'BE',
#   'artist': '방탄소년단',
#   'rank': 59,
#   'like': 84247},
#  {'song_no': '32614125',
#   'title': '사랑하게 될 줄 알았어',
#   'album': '슬기로운 의사생활 OST Part 11',
#   'artist': '전미도',
#   'rank': 60,
#   'like': 128254},
#  {'song_no': '32996210',
#   'title': '행복해',
#   'album': 'Happy',
#   'artist': '송하예',
#   'rank': 61,
#   'like': 19392},
#  {'song_no': '32486613',
#   'title': '처음처럼',
#   'album': 'CEREMONIA',
#   'artist': '엠씨더맥스 (M.C the MAX)',
#   'rank': 62,
#   'like': 98838},
#  {'song_no': '31984204',
#   'title': '안녕',
#   'album': '호텔 델루나 OST Part.10',
#   'artist': '폴킴',
#   'rank': 63,
#   'like': 181122},
#  {'song_no': '32508053',
#   'title': '이제 나만 믿어요',
#   'album': '내일은 미스터트롯 우승자 특전곡',
#   'artist': '임영웅',
#   'rank': 64,
#   'like': 102927},
#  {'song_no': '33034623',
#   'title': 'AYA',
#   'album': 'TRAVEL',
#   'artist': '마마무 (Mamamoo)',
#   'rank': 65,
#   'like': 26602},
#  {'song_no': '32137576',
#   'title': "Don't Start Now",
#   'album': 'Future Nostalgia',
#   'artist': 'Dua Lipa',
#   'rank': 66,
#   'like': 125679},
#  {'song_no': '32399830',
#   'title': 'ON',
#   'album': 'MAP OF THE SOUL : 7',
#   'artist': '방탄소년단',
#   'rank': 67,
#   'like': 253239},
#  {'song_no': '33077240',
#   'title': 'Stay',
#   'album': 'BE',
#   'artist': '방탄소년단',
#   'rank': 68,
#   'like': 79378},
#  {'song_no': '32906021',
#   'title': '별을 담은 시 (Ode To The Stars)',
#   'album': 'Red Moon : Ode To The Stars',
#   'artist': '마크툽 (MAKTUB)',
#   'rank': 69,
#   'like': 30837},
#  {'song_no': '31388145',
#   'title': '너를 만나',
#   'album': '너를 만나',
#   'artist': '폴킴',
#   'rank': 70,
#   'like': 274819},
#  {'song_no': '33077239',
#   'title': '병',
#   'album': 'BE',
#   'artist': '방탄소년단',
#   'rank': 71,
#   'like': 80236},
#  {'song_no': '33064355',
#   'title': 'HAPPENING',
#   'album': 'HAPPENING',
#   'artist': 'AKMU (악동뮤지션)',
#   'rank': 72,
#   'like': 27345},
#  {'song_no': '31509376',
#   'title': '12:45 (Stripped)',
#   'album': '12:45 (Stripped)',
#   'artist': 'Etham',
#   'rank': 73,
#   'like': 97024},
#  {'song_no': '32143487',
#   'title': 'Love poem',
#   'album': 'Love poem',
#   'artist': '아이유',
#   'rank': 74,
#   'like': 277154},
#  {'song_no': '32313543',
#   'title': '아무노래',
#   'album': '아무노래',
#   'artist': '지코 (ZICO)',
#   'rank': 75,
#   'like': 250250},
#  {'song_no': '32345931',
#   'title': '시작',
#   'album': '이태원 클라쓰 OST Part.2',
#   'artist': '가호 (Gaho)',
#   'rank': 76,
#   'like': 193678},
#  {'song_no': '32961716',
#   'title': 'Pretty Savage',
#   'album': 'THE ALBUM',
#   'artist': 'BLACKPINK',
#   'rank': 77,
#   'like': 45873},
#  {'song_no': '32833393',
#   'title': '덤디덤디 (DUMDi DUMDi)',
#   'album': '덤디덤디 (DUMDi DUMDi)',
#   'artist': '(여자)아이들',
#   'rank': 78,
#   'like': 88942},
#  {'song_no': '33067476',
#   'title': 'Black Mamba',
#   'album': 'Black Mamba',
#   'artist': 'aespa',
#   'rank': 79,
#   'like': 21908},
#  {'song_no': '32915886',
#   'title': '축하해 (Prod. By VAN.C)',
#   'album': '축하해',
#   'artist': '오반',
#   'rank': 80,
#   'like': 34561},
#  {'song_no': '5475060',
#   'title': 'Santa Tell Me',
#   'album': 'Santa Tell Me',
#   'artist': 'Ariana Grande',
#   'rank': 81,
#   'like': 162739},
#  {'song_no': '32122539',
#   'title': 'Maniac',
#   'album': 'Maniac',
#   'artist': 'Conan Gray',
#   'rank': 82,
#   'like': 109584},
#  {'song_no': '31341518',
#   'title': 'Paris In The Rain',
#   'album': 'I met you when I was 18. (the playlist)',
#   'artist': 'Lauv',
#   'rank': 83,
#   'like': 235014},
#  {'song_no': '32902881',
#   'title': '밤새 (취향저격 그녀 X 카더가든)',
#   'album': '밤새 (취향저격 그녀 X 카더가든)',
#   'artist': '카더가든',
#   'rank': 84,
#   'like': 34645},
#  {'song_no': '33029109',
#   'title': '도망가',
#   'album': 'TAKE',
#   'artist': 'MINO (송민호)',
#   'rank': 85,
#   'like': 36654},
#  {'song_no': '31703498',
#   'title': '시든 꽃에 물을 주듯',
#   'album': '시든 꽃에 물을 주듯',
#   'artist': 'HYNN (박혜원)',
#   'rank': 86,
#   'like': 178421},
#  {'song_no': '32377231',
#   'title': '그때 그 아인',
#   'album': '이태원 클라쓰 OST Part.6',
#   'artist': '김필',
#   'rank': 87,
#   'like': 101181},
#  {'song_no': '32616054',
#   'title': '취했나봐',
#   'album': '취했나봐',
#   'artist': '황인욱',
#   'rank': 88,
#   'like': 41026},
#  {'song_no': '32860419',
#   'title': 'Not Shy',
#   'album': 'Not Shy',
#   'artist': 'ITZY (있지)',
#   'rank': 89,
#   'like': 57046},
#  {'song_no': '32734819',
#   'title': '첫 줄',
#   'album': 'Dear',
#   'artist': '신용재 (2F)',
#   'rank': 90,
#   'like': 35587},
#  {'song_no': '32725022',
#   'title': '보라빛 밤 (pporappippam)',
#   'album': '보라빛 밤 (pporappippam)',
#   'artist': '선미',
#   'rank': 91,
#   'like': 82347},
#  {'song_no': '32734372',
#   'title': 'Summer Hate (Feat. 비)',
#   'album': 'RANDOM BOX',
#   'artist': '지코 (ZICO)',
#   'rank': 92,
#   'like': 103628},
#  {'song_no': '32473998',
#   'title': '좋은 사람 있으면 소개시켜줘',
#   'album': '슬기로운 의사생활 OST Part 2',
#   'artist': '조이 (JOY)',
#   'rank': 93,
#   'like': 106746},
#  {'song_no': '32889003',
#   'title': 'Ice Cream (with Selena Gomez)',
#   'album': 'Ice Cream (with Selena Gomez)',
#   'artist': 'BLACKPINK',
#   'rank': 94,
#   'like': 71576},
#  {'song_no': '31314144',
#   'title': '가을 타나 봐',
#   'album': '가을 타나 봐',
#   'artist': '바이브',
#   'rank': 95,
#   'like': 151290},
#  {'song_no': '33027247',
#   'title': '너의 곁에만 맴돌아',
#   'album': '너의 곁에만 맴돌아',
#   'artist': '노을',
#   'rank': 96,
#   'like': 13427},
#  {'song_no': '32273582',
#   'title': 'Psycho',
#   'album': '‘The ReVe Festival’ Finale',
#   'artist': 'Red Velvet (레드벨벳)',
#   'rank': 97,
#   'like': 207279},
#  {'song_no': '31701428',
#   'title': 'bad guy',
#   'album': 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?',
#   'artist': 'Billie Eilish',
#   'rank': 98,
#   'like': 240669},
#  {'song_no': '31768993',
#   'title': 'Painkiller',
#   'album': 'Painkiller',
#   'artist': 'Ruel',
#   'rank': 99,
#   'like': 115360},
#  {'song_no': '32698765',
#   'title': 'Into the I-LAND',
#   'album': 'I-LAND Part.1 Signal Song',
#   'artist': '아이유',
#   'rank': 100,
#   'like': 110457}]

# %% [markdown]
# # `"방탄소년단"` 의 곡명만 출력하는 코드

# %%
for data in melon_top100:
    print(data)
# Out:
# {'song_no': '30244931', 'title': '봄날', 'album': 'YOU NEVER WALK ALONE', 'artist': '방탄소년단', 'rank': 48, 'like': 516046}
# {'song_no': '31737197', 'title': '작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)', 'album': 'MAP OF THE SOUL : PERSONA', 'artist': '방탄소년단', 'rank': 31, 'like': 406370}
# {'song_no': '32872978', 'title': 'Dynamite', 'album': 'Dynamite (DayTime Version)', 'artist': '방탄소년단', 'rank': 2, 'like': 360682}
# {'song_no': '30962526', 'title': '모든 날, 모든 순간 (Every day, Every Moment)', 'album': '`키스 먼저 할까요?` OST Part.3', 'artist': '폴킴', 'rank': 35, 'like': 352216}
# {'song_no': '31029291', 'title': '2002', 'album': 'Speak Your Mind (Deluxe)', 'artist': 'Anne-Marie', 'rank': 54, 'like': 344218}
# {'song_no': '32578498', 'title': '에잇(Prod.&Feat. SUGA of BTS)', 'album': '에잇', 'artist': '아이유', 'rank': 20, 'like': 330752}
# {'song_no': '32061975', 'title': '어떻게 이별까지 사랑하겠어, 널 사랑하는 거지', 'album': '항해', 'artist': 'AKMU (악동뮤지션)', 'rank': 16, 'like': 324195}
# {'song_no': '32143487', 'title': 'Love poem', 'album': 'Love poem', 'artist': '아이유', 'rank': 74, 'like': 277154}
# {'song_no': '32183386', 'title': 'Blueming', 'album': 'Love poem', 'artist': '아이유', 'rank': 32, 'like': 276419}
# {'song_no': '31388145', 'title': '너를 만나', 'album': '너를 만나', 'artist': '폴킴', 'rank': 70, 'like': 274819}
# {'song_no': '32003395', 'title': '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야', 'album': '멜로가 체질 OST Part 3', 'artist': '장범준', 'rank': 22, 'like': 270148}
# {'song_no': '32399830', 'title': 'ON', 'album': 'MAP OF THE SOUL : 7', 'artist': '방탄소년단', 'rank': 67, 'like': 253239}
# {'song_no': '32313543', 'title': '아무노래', 'album': '아무노래', 'artist': '지코 (ZICO)', 'rank': 75, 'like': 250250}
# {'song_no': '32224272', 'title': 'METEOR', 'album': 'Boyhood', 'artist': '창모 (CHANGMO)', 'rank': 33, 'like': 242139}
# {'song_no': '31701428', 'title': 'bad guy', 'album': 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?', 'artist': 'Billie Eilish', 'rank': 98, 'like': 240669}
# {'song_no': '31341518', 'title': 'Paris In The Rain', 'album': 'I met you when I was 18. (the playlist)', 'artist': 'Lauv', 'rank': 83, 'like': 235014}
# {'song_no': '32790516', 'title': '다시 여기 바닷가', 'album': '다시 여기 바닷가', 'artist': '싹쓰리 (유두래곤, 린다G, 비룡)', 'rank': 58, 'like': 227758}
# {'song_no': '31853557', 'title': '오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)', 'album': 'Red Moon : To You My Light', 'artist': '마크툽 (MAKTUB)', 'rank': 47, 'like': 221618}
# {'song_no': '32273582', 'title': 'Psycho', 'album': '‘The ReVe Festival’ Finale', 'artist': 'Red Velvet (레드벨벳)', 'rank': 97, 'like': 207279}
# {'song_no': '32491274', 'title': '아로하', 'album': '슬기로운 의사생활 OST Part 3', 'artist': '조정석', 'rank': 29, 'like': 205454}
# {'song_no': '3894276', 'title': '오래된 노래', 'album': '오래된 노래', 'artist': '스탠딩 에그', 'rank': 10, 'like': 200112}
# {'song_no': '32345931', 'title': '시작', 'album': '이태원 클라쓰 OST Part.2', 'artist': '가호 (Gaho)', 'rank': 76, 'like': 193678}
# {'song_no': '32378104', 'title': '마음을 드려요', 'album': '사랑의 불시착 OST Part 11', 'artist': '아이유', 'rank': 50, 'like': 181135}
# {'song_no': '31984204', 'title': '안녕', 'album': '호텔 델루나 OST Part.10', 'artist': '폴킴', 'rank': 63, 'like': 181122}
# {'song_no': '30773554', 'title': 'Downtown Baby', 'album': 'Downtown Baby', 'artist': '블루 (BLOO)', 'rank': 45, 'like': 179878}
# {'song_no': '31703498', 'title': '시든 꽃에 물을 주듯', 'album': '시든 꽃에 물을 주듯', 'artist': 'HYNN (박혜원)', 'rank': 86, 'like': 178421}
# {'song_no': '32156286', 'title': '늦은 밤 너의 집 앞 골목길에서', 'album': '늦은 밤 너의 집 앞 골목길에서', 'artist': '노을', 'rank': 26, 'like': 168164}
# {'song_no': '32720013', 'title': 'How You Like That', 'album': 'How You Like That', 'artist': 'BLACKPINK', 'rank': 25, 'like': 164117}
# {'song_no': '5475060', 'title': 'Santa Tell Me', 'album': 'Santa Tell Me', 'artist': 'Ariana Grande', 'rank': 81, 'like': 162739}
# {'song_no': '32559781', 'title': '살짝 설렜어 (Nonstop)', 'album': 'NONSTOP', 'artist': '오마이걸 (OH MY GIRL)', 'rank': 56, 'like': 162167}
# {'song_no': '32559782', 'title': 'Dolphin', 'album': 'NONSTOP', 'artist': '오마이걸 (OH MY GIRL)', 'rank': 28, 'like': 159371}
# {'song_no': '32978341', 'title': "DON'T TOUCH ME", 'album': "DON'T TOUCH ME", 'artist': '환불원정대', 'rank': 12, 'like': 157899}
# {'song_no': '32794652', 'title': '취기를 빌려 (취향저격 그녀 X 산들)', 'album': '취기를 빌려 (취향저격 그녀 X 산들)', 'artist': '산들', 'rank': 7, 'like': 156888}
# {'song_no': '32725013', 'title': '마리아 (Maria)', 'album': 'María', 'artist': '화사 (Hwa Sa)', 'rank': 30, 'like': 153184}
# {'song_no': '31314144', 'title': '가을 타나 봐', 'album': '가을 타나 봐', 'artist': '바이브', 'rank': 95, 'like': 151290}
# {'song_no': '32961718', 'title': 'Lovesick Girls', 'album': 'THE ALBUM', 'artist': 'BLACKPINK', 'rank': 6, 'like': 150233}
# {'song_no': '33077234', 'title': 'Life Goes On', 'album': 'BE', 'artist': '방탄소년단', 'rank': 5, 'like': 150052}
# {'song_no': '32055419', 'title': 'Memories', 'album': 'Memories', 'artist': 'Maroon 5', 'rank': 43, 'like': 147050}
# {'song_no': '14776', 'title': 'All I Want For Christmas Is You', 'album': 'Merry Christmas (Deluxe Anniversary Edition)', 'artist': 'Mariah Carey', 'rank': 53, 'like': 143985}
# {'song_no': '31979846', 'title': 'Dance Monkey', 'album': 'The Kids Are Coming', 'artist': 'Tones And I', 'rank': 42, 'like': 142888}
# {'song_no': '32438894', 'title': '어떻게 지내 (Prod. By VAN.C)', 'album': '어떻게 지내', 'artist': '오반', 'rank': 24, 'like': 133343}
# {'song_no': '32962258', 'title': 'Savage Love (Laxed - Siren Beat) (BTS Remix)', 'album': 'Savage Love (Laxed - Siren Beat) [BTS Remix]', 'artist': 'Jawsh 685', 'rank': 11, 'like': 128323}
# {'song_no': '32614125', 'title': '사랑하게 될 줄 알았어', 'album': '슬기로운 의사생활 OST Part 11', 'artist': '전미도', 'rank': 60, 'like': 128254}
# {'song_no': '32137576', 'title': "Don't Start Now", 'album': 'Future Nostalgia', 'artist': 'Dua Lipa', 'rank': 66, 'like': 125679}
# {'song_no': '32808616', 'title': '홀로', 'album': '홀로', 'artist': '이하이', 'rank': 38, 'like': 118371}
# {'song_no': '31768993', 'title': 'Painkiller', 'album': 'Painkiller', 'artist': 'Ruel', 'rank': 99, 'like': 115360}
# {'song_no': '32698765', 'title': 'Into the I-LAND', 'album': 'I-LAND Part.1 Signal Song', 'artist': '아이유', 'rank': 100, 'like': 110457}
# {'song_no': '32122539', 'title': 'Maniac', 'album': 'Maniac', 'artist': 'Conan Gray', 'rank': 82, 'like': 109584}
# {'song_no': '32473998', 'title': '좋은 사람 있으면 소개시켜줘', 'album': '슬기로운 의사생활 OST Part 2', 'artist': '조이 (JOY)', 'rank': 93, 'like': 106746}
# {'song_no': '32734372', 'title': 'Summer Hate (Feat. 비)', 'album': 'RANDOM BOX', 'artist': '지코 (ZICO)', 'rank': 92, 'like': 103628}
# {'song_no': '32508053', 'title': '이제 나만 믿어요', 'album': '내일은 미스터트롯 우승자 특전곡', 'artist': '임영웅', 'rank': 64, 'like': 102927}
# {'song_no': '32377231', 'title': '그때 그 아인', 'album': '이태원 클라쓰 OST Part.6', 'artist': '김필', 'rank': 87, 'like': 101181}
# {'song_no': '32486613', 'title': '처음처럼', 'album': 'CEREMONIA', 'artist': '엠씨더맥스 (M.C the MAX)', 'rank': 62, 'like': 98838}
# {'song_no': '31509376', 'title': '12:45 (Stripped)', 'album': '12:45 (Stripped)', 'artist': 'Etham', 'rank': 73, 'like': 97024}
# {'song_no': '32825454', 'title': '눈누난나 (NUNU NANA)', 'album': 'NUNA', 'artist': '제시 (Jessi)', 'rank': 27, 'like': 95407}
# {'song_no': '33077590', 'title': 'VVS (Feat. JUSTHIS) (Prod. GroovyRoom)', 'album': '쇼미더머니 9 Episode 1', 'artist': '미란이', 'rank': 1, 'like': 94347}
# {'song_no': '32187544', 'title': '우리 왜 헤어져야 해', 'album': '우리 왜 헤어져야 해', 'artist': '신예영', 'rank': 49, 'like': 92027}
# {'song_no': '33077236', 'title': 'Blue & Grey', 'album': 'BE', 'artist': '방탄소년단', 'rank': 40, 'like': 90841}
# {'song_no': '33077235', 'title': '내 방을 여행하는 법', 'album': 'BE', 'artist': '방탄소년단', 'rank': 36, 'like': 90323}
# {'song_no': '32833393', 'title': '덤디덤디 (DUMDi DUMDi)', 'album': '덤디덤디 (DUMDi DUMDi)', 'artist': '(여자)아이들', 'rank': 78, 'like': 88942}
# {'song_no': '33077238', 'title': '잠시', 'album': 'BE', 'artist': '방탄소년단', 'rank': 59, 'like': 84247}
# {'song_no': '32725022', 'title': '보라빛 밤 (pporappippam)', 'album': '보라빛 밤 (pporappippam)', 'artist': '선미', 'rank': 91, 'like': 82347}
# {'song_no': '33013877', 'title': '잠이 오질 않네요', 'album': '잠이 오질 않네요', 'artist': '장범준', 'rank': 3, 'like': 82061}
# {'song_no': '32871975', 'title': '내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)', 'album': '내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)', 'artist': '규현 (KYUHYUN)', 'rank': 13, 'like': 80470}
# {'song_no': '33077239', 'title': '병', 'album': 'BE', 'artist': '방탄소년단', 'rank': 71, 'like': 80236}
# {'song_no': '33077240', 'title': 'Stay', 'album': 'BE', 'artist': '방탄소년단', 'rank': 68, 'like': 79378}
# {'song_no': '32998018', 'title': '힘든 건 사랑이 아니다', 'album': '힘든 건 사랑이 아니다', 'artist': '임창정', 'rank': 4, 'like': 78971}
# {'song_no': '32889003', 'title': 'Ice Cream (with Selena Gomez)', 'album': 'Ice Cream (with Selena Gomez)', 'artist': 'BLACKPINK', 'rank': 94, 'like': 71576}
# {'song_no': '32853712', 'title': 'When We Disco (Duet with 선미)', 'album': 'When We Disco', 'artist': '박진영', 'rank': 15, 'like': 67007}
# {'song_no': '32860419', 'title': 'Not Shy', 'album': 'Not Shy', 'artist': 'ITZY (있지)', 'rank': 89, 'like': 57046}
# {'song_no': '32651098', 'title': '사랑은 지날수록 더욱 선명하게 남아', 'album': '한 걸음 : 흔적', 'artist': '전상근', 'rank': 41, 'like': 52937}
# {'song_no': '33043504', 'title': '가을밤에 든 생각', 'album': '잔나비 소곡집 l', 'artist': '잔나비', 'rank': 21, 'like': 51252}
# {'song_no': '32947184', 'title': 'Bad Boy', 'album': 'Bad Boy', 'artist': '청하', 'rank': 51, 'like': 50301}
# {'song_no': '33001672', 'title': '딩가딩가 (Dingga)', 'album': '딩가딩가 (Dingga)', 'artist': '마마무 (Mamamoo)', 'rank': 14, 'like': 48781}
# {'song_no': '32777869', 'title': '거짓말이라도 해서 널 보고싶어', 'album': '거짓말이라도 해서 널 보고싶어', 'artist': '백지영', 'rank': 34, 'like': 48712}
# {'song_no': '32961716', 'title': 'Pretty Savage', 'album': 'THE ALBUM', 'artist': 'BLACKPINK', 'rank': 77, 'like': 45873}
# {'song_no': '32999763', 'title': '놓아줘 (with 태연)', 'album': 'with HER', 'artist': 'Crush', 'rank': 39, 'like': 45861}
# {'song_no': '33016659', 'title': 'I CAN’T STOP ME', 'album': 'Eyes wide open', 'artist': 'TWICE (트와이스)', 'rank': 19, 'like': 44688}
# {'song_no': '33011180', 'title': '나랑 같이 걸을래 (바른연애 길잡이 X 적재)', 'album': '나랑 같이 걸을래 (바른연애 길잡이 X 적재)', 'artist': '적재', 'rank': 23, 'like': 41638}
# {'song_no': '33061995', 'title': '밤하늘의 별을(2020)', 'album': '밤하늘의 별을(2020)', 'artist': '경서', 'rank': 9, 'like': 41575}
# {'song_no': '32616054', 'title': '취했나봐', 'album': '취했나봐', 'artist': '황인욱', 'rank': 88, 'like': 41026}
# {'song_no': '33029109', 'title': '도망가', 'album': 'TAKE', 'artist': 'MINO (송민호)', 'rank': 85, 'like': 36654}
# {'song_no': '33077591', 'title': 'Freak (Prod. Slom)', 'album': '쇼미더머니 9 Episode 1', 'artist': '릴보이 (lIlBOI)', 'rank': 8, 'like': 35758}
# {'song_no': '32734819', 'title': '첫 줄', 'album': 'Dear', 'artist': '신용재 (2F)', 'rank': 90, 'like': 35587}
# {'song_no': '32525311', 'title': '사실 나는 (Feat.전건호)', 'album': '사실 나는', 'artist': '경서예지', 'rank': 44, 'like': 35219}
# {'song_no': '32902881', 'title': '밤새 (취향저격 그녀 X 카더가든)', 'album': '밤새 (취향저격 그녀 X 카더가든)', 'artist': '카더가든', 'rank': 84, 'like': 34645}
# {'song_no': '32915886', 'title': '축하해 (Prod. By VAN.C)', 'album': '축하해', 'artist': '오반', 'rank': 80, 'like': 34561}
# {'song_no': '32570501', 'title': '서면역에서', 'album': '서면역에서', 'artist': '순순희', 'rank': 37, 'like': 32925}
# {'song_no': '33016550', 'title': '너도 아는', 'album': '너도 아는', 'artist': '폴킴', 'rank': 57, 'like': 32034}
# {'song_no': '32906021', 'title': '별을 담은 시 (Ode To The Stars)', 'album': 'Red Moon : Ode To The Stars', 'artist': '마크툽 (MAKTUB)', 'rank': 69, 'like': 30837}
# {'song_no': '33061829', 'title': '뻔한남자', 'album': '뻔한남자', 'artist': '이승기', 'rank': 18, 'like': 30712}
# {'song_no': '33064355', 'title': 'HAPPENING', 'album': 'HAPPENING', 'artist': 'AKMU (악동뮤지션)', 'rank': 72, 'like': 27345}
# {'song_no': '33034623', 'title': 'AYA', 'album': 'TRAVEL', 'artist': '마마무 (Mamamoo)', 'rank': 65, 'like': 26602}
# {'song_no': '32998020', 'title': '소확행', 'album': '힘든 건 사랑이 아니다', 'artist': '임창정', 'rank': 55, 'like': 24351}
# {'song_no': '33077588', 'title': '원해 (Feat. 팔로알토) (Prod. 코드 쿤스트)', 'album': '쇼미더머니 9 Episode 1', 'artist': '스윙스', 'rank': 17, 'like': 22472}
# {'song_no': '33067476', 'title': 'Black Mamba', 'album': 'Black Mamba', 'artist': 'aespa', 'rank': 79, 'like': 21908}
# {'song_no': '33002813', 'title': '사랑 못해, 남들 쉽게 다 하는 거', 'album': '사랑 못해, 남들 쉽게 다 하는 거', 'artist': '먼데이 키즈 (Monday Kiz)', 'rank': 52, 'like': 20733}
# {'song_no': '32996210', 'title': '행복해', 'album': 'Happy', 'artist': '송하예', 'rank': 61, 'like': 19392}
# {'song_no': '33077589', 'title': '윈윈 (Feat. 개코, BewhY) (Prod. BewhY)', 'album': '쇼미더머니 9 Episode 1', 'artist': '허성현 (Rose de Penny)', 'rank': 46, 'like': 19119}
# {'song_no': '33027247', 'title': '너의 곁에만 맴돌아', 'album': '너의 곁에만 맴돌아', 'artist': '노을', 'rank': 96, 'like': 13427}

# %%
song_list = []
for data in melon_top100:
    if(data["artist"] == "방탄소년단"):
        song_list.append(data["title"])
song_list
# Out:
# ['봄날',
#  '작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)',
#  'Dynamite',
#  'ON',
#  'Life Goes On',
#  'Blue & Grey',
#  '내 방을 여행하는 법',
#  '잠시',
#  '병',
#  'Stay']

# %% [markdown]
# # 2. 곡명에 "가을"이 들어가는 곡명만 출력하는 코드
#     - Hint: 포함여부 = "가을" in 곡명

# %%
song_list = []
for data in melon_top100:
    if("가을" in data["title"]):
        song_list.append(data["title"])
song_list
# Out:
# ['가을 타나 봐', '가을밤에 든 생각']

# %% [markdown]
# # 3. 좋아요 수가 200,000이 넘는 곡수를 구하는 코드
#     - Hint: int(좋아요) > 200000

# %%
song_cnt = 0
for data in melon_top100:
    if(data["like"] > 200000):
        song_cnt += 1
song_cnt
# Out:
# 21

# %% [markdown]
# # 4. 가수 별 곡수를 출력하는 코드
#     - Hint: `dict` 자료구조 활용

# %%
import requests
from collections import Counter

question_4_list = {}
for data in melon_top100:
    key = data["artist"]
    if question_4_list.get(key):
        question_4_list[key] += 1
    else:
        question_4_list[key] = 1
question_4_list
# Out:
# {'방탄소년단': 10,
#  '폴킴': 4,
#  'Anne-Marie': 1,
#  '아이유': 5,
#  'AKMU (악동뮤지션)': 2,
#  '장범준': 2,
#  '지코 (ZICO)': 2,
#  '창모 (CHANGMO)': 1,
#  'Billie Eilish': 1,
#  'Lauv': 1,
#  '싹쓰리 (유두래곤, 린다G, 비룡)': 1,
#  '마크툽 (MAKTUB)': 2,
#  'Red Velvet (레드벨벳)': 1,
#  '조정석': 1,
#  '스탠딩 에그': 1,
#  '가호 (Gaho)': 1,
#  '블루 (BLOO)': 1,
#  'HYNN (박혜원)': 1,
#  '노을': 2,
#  'BLACKPINK': 4,
#  'Ariana Grande': 1,
#  '오마이걸 (OH MY GIRL)': 2,
#  '환불원정대': 1,
#  '산들': 1,
#  '화사 (Hwa Sa)': 1,
#  '바이브': 1,
#  'Maroon 5': 1,
#  'Mariah Carey': 1,
#  'Tones And I': 1,
#  '오반': 2,
#  'Jawsh 685': 1,
#  '전미도': 1,
#  'Dua Lipa': 1,
#  '이하이': 1,
#  'Ruel': 1,
#  'Conan Gray': 1,
#  '조이 (JOY)': 1,
#  '임영웅': 1,
#  '김필': 1,
#  '엠씨더맥스 (M.C the MAX)': 1,
#  'Etham': 1,
#  '제시 (Jessi)': 1,
#  '미란이': 1,
#  '신예영': 1,
#  '(여자)아이들': 1,
#  '선미': 1,
#  '규현 (KYUHYUN)': 1,
#  '임창정': 2,
#  '박진영': 1,
#  'ITZY (있지)': 1,
#  '전상근': 1,
#  '잔나비': 1,
#  '청하': 1,
#  '마마무 (Mamamoo)': 2,
#  '백지영': 1,
#  'Crush': 1,
#  'TWICE (트와이스)': 1,
#  '적재': 1,
#  '경서': 1,
#  '황인욱': 1,
#  'MINO (송민호)': 1,
#  '릴보이 (lIlBOI)': 1,
#  '신용재 (2F)': 1,
#  '경서예지': 1,
#  '카더가든': 1,
#  '순순희': 1,
#  '이승기': 1,
#  '스윙스': 1,
#  'aespa': 1,
#  '먼데이 키즈 (Monday Kiz)': 1,
#  '송하예': 1,
#  '허성현 (Rose de Penny)': 1}

# %% [markdown]
# # 5. 좋아요 수로 TOP10의 가수와 곡명, 좋아요수 출력하는 코드
#     - Hint : 리스트에는 sort 함수가 제공되고 있으며, 빌트인 함수에는 `sorted`가 제공됩니다.

# %%
melon_top100.sort(key = lambda x : x["like"],reverse=True)
melon_top10 = melon_top100[:10]

melon_list = []
for data in melon_top10:
    melon_list.append({
        "artist":data["artist"],
        "title":data["title"],
        "like":data["like"],
    })
melon_list
# Out:
# [{'artist': '방탄소년단', 'title': '봄날', 'like': 516046},
#  {'artist': '방탄소년단',
#   'title': '작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)',
#   'like': 406370},
#  {'artist': '방탄소년단', 'title': 'Dynamite', 'like': 360682},
#  {'artist': '폴킴',
#   'title': '모든 날, 모든 순간 (Every day, Every Moment)',
#   'like': 352216},
#  {'artist': 'Anne-Marie', 'title': '2002', 'like': 344218},
#  {'artist': '아이유', 'title': '에잇(Prod.&Feat. SUGA of BTS)', 'like': 330752},
#  {'artist': 'AKMU (악동뮤지션)',
#   'title': '어떻게 이별까지 사랑하겠어, 널 사랑하는 거지',
#   'like': 324195},
#  {'artist': '아이유', 'title': 'Love poem', 'like': 277154},
#  {'artist': '아이유', 'title': 'Blueming', 'like': 276419},
#  {'artist': '폴킴', 'title': '너를 만나', 'like': 274819}]
